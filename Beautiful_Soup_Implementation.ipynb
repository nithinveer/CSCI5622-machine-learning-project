# %%
from bs4 import BeautifulSoup

# %%
import urllib3

# %%
url = "https://www.tripadvisor.com/Hotel_Review-g41129-d263087-Reviews-or20-Hampton_Inn_Elkton-Elkton_Maryland.html#REVIEWS"

# %%
url = "https://www.tripadvisor.com/Hotel_Review-g41129-d263087-Reviews-or440-Hampton_Inn_Elkton-Elkton_Maryland.html#REVIEWS"

# %%
http = urllib3.PoolManager()
res = http.request("GET",url)
soup = BeautifulSoup(res.data)
#content = urllib3.urlopen(url).read()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\dell\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://static.tacdn.com/favicon.ico" id="favicon" rel="icon" type="image/x-icon"/>
#   <link color="#00a680" href="https://static.tacdn.com/img2/icons/ta_square.svg" rel="mask-icon" sizes="any"/>
#   <meta content="#00a680" name="theme-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <script type="text/javascript">
#    window.taRollupsAreAsync = true;
#   </script>
#   <title>
#    HAMPTON INN ELKTON $104 ($̶1̶4̶1̶) - Updated 2019 Prices &amp; Hotel Reviews - MD - TripAdvisor
#   </title>
#   <meta content="Now $104 (Was $̶1̶4̶1̶) on TripAdvisor: Hampton Inn Elkton, Elkton. See 446 traveler reviews, 29 candid photos, and great deals for Hampton Inn Elkton, ranked #2 of 8 hotels in Elkton and rated 4.5 of 5 at TripAdvisor." name="description"/>
# ...

# %%
x = soup.find_all("div",{"class": "cPQsENeY"})
for v_0 in x[1:]:
    print(v_0.text)
#print(x[1:])
# Out:
# Going up I-95 and need to stop last night before I killed someone, so this place looked good to stay. I'm glad we did...We just came off our vacation from MiamiBeach,FL..The FL.Keys and MyrtleBeach,SC all driving :) but anyway this was a clean decent place to stay, great small breakfast clean tub pillows nice and soft and so was the bed, nice big TV, great size rooms and clean hallways with no nasty hallway hotel smell.    Yes I would stay here again and again, I just wish all of them were like this one. There is one little down side....the room that i was in had a nice train in back of it but it wasn't loud but could be heard but the hotel seems to be well nice and thick so the noise wasn't loud loud but could be heard so be advised.   Other than that which is not a big deal,…
# ...

# %%
x1 = soup.find_all("span",{"class":"hotels-review-list-parts-EventDate__event_date--CRXs4"})
for v_1 in x1:
    print(v_1.text)
# Out:
# Date of stay: September 2007
# Date of stay: November 2006
# Date of stay: January 2007

# %%
x2 = soup.find_all("a",{"class":"hotels-review-list-parts-ReviewTitle__reviewTitleText--3QrTy"})
for v_2 in x2:
    print(v_2.text)
#print(x2)
# Out:
# Great stay, good continental breakfast
# Problems but they were very well dealt with
# Pleasureable stay

# %%
x_sample = soup.find_all("span",{"class":"tWzdVpH_ dnQ8TT87"})
for v_sample in x_sample:
    print(v_sample['content'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-68081554357b> in <module>()
#       1 x_sample = soup.find_all("span",{"class":"tWzdVpH_ dnQ8TT87"})
#       2 for v_sample in x_sample:
# ----> 3     print(v_sample['content'])
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 'content'

# %%
# Out:
# <div class="hotels-review-list-parts-RatingLine__bubbles--1oCI4" data-test-target="review-rating"><span class="tWzdVpH_ dnQ8TT87"></span></div>

# %%
x3 = soup.find_all("div",{"class":"hotels-review-list-parts-SingleReview__mainCol--2XgHm"})
for v_3 in x3:
    print(v_3['data-reviewid'])
#print(x3)
#for v_3 in x3:
# Out:
# 8615840
# 6785606
# 6606687

# %%
url_new = "https://www.tripadvisor.com/ShowUserReviews-g41129-d263087-r8615840-Hampton_Inn_Elkton-Elkton_Maryland.html"
http1 = urllib3.PoolManager()
res2 = http1.request("GET",url_new)
soup1 = BeautifulSoup(res2.data)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\dell\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print(soup1.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://static.tacdn.com/favicon.ico" id="favicon" rel="icon" type="image/x-icon"/>
#   <link color="#00a680" href="https://static.tacdn.com/img2/icons/ta_square.svg" rel="mask-icon" sizes="any"/>
#   <meta content="#00a680" name="theme-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <script type="text/javascript">
#    window.taRollupsAreAsync = true;
#   </script>
#   <title>
#    Great stay, good continental breakfast - Review of Hampton Inn Elkton, Elkton, MD - TripAdvisor
#   </title>
#   <meta content="TripAdvisor" property="al:ios:app_name"/>
#   <meta content="284876795" property="al:ios:app_store_id"/>
#   <meta content="284876795" name="twitter:app:id:ipad" property="twitter:app:id:ipad"/>
# ...

# %%
class_to_rating = {
    "bubble_10": 1,
    "bubble_15": 1.5,
    "bubble_20": 2,
    "bubble_25": 2.5,
    "bubble_30": 3,
    "bubble_35": 3.5,
    "bubble_40": 4,
    "bubble_45": 4.5,
    "bubble_50": 5
}

# %%
x3 = soup1.find("div",{"class":"rating-list"})
print(x3)
# Out:
# <div class="rating-list"><ul class="recommend"><li><div class="recommend-titleInline"><span class="trip_type_label">Trip type: </span>Traveled as a couple</div><ul class="recommend-column first"><li class="recommend-answer"><div class="ui_bubble_rating bubble_50"></div><div class="recommend-description">Value</div></li><li class="recommend-answer"><div class="ui_bubble_rating bubble_50"></div><div class="recommend-description">Location</div></li><li class="recommend-answer"><div class="ui_bubble_rating bubble_50"></div><div class="recommend-description">Check in / front desk</div></li></ul><ul class="recommend-column"><li class="recommend-answer"><div class="ui_bubble_rating bubble_50"></div><div class="recommend-description">Rooms</div></li><li class="recommend-answer"><div class="ui_bubble_rating bubble_50"></div><div class="recommend-description">Cleanliness</div></li><li class="recommend-answer"><div class="ui_bubble_rating bubble_50"></div><div class="recommend-description">Serv
# ...

# %%
e2 = x3.select(".ui_bubble_rating")
print(e2)
# Out:
# [<div class="ui_bubble_rating bubble_50"></div>, <div class="ui_bubble_rating bubble_50"></div>, <div class="ui_bubble_rating bubble_50"></div>, <div class="ui_bubble_rating bubble_50"></div>, <div class="ui_bubble_rating bubble_50"></div>, <div class="ui_bubble_rating bubble_50"></div>, <div class="ui_bubble_rating bubble_50"></div>]

# %%
e1 = soup1.select(".ui_bubble_rating")
e3 = []
e3.append(e1[0])

# %%
key_list = []
#for v_4 in x3:
#    print(v_4.text)
for v_4 in e3:
    key_list.append(v_4["class"][1])
#key_list.append()
for v_4 in e2:
    key_list.append(v_4["class"][1])
print(key_list)
#print(type(e1))
# Out:
# ['bubble_50', 'bubble_50', 'bubble_50', 'bubble_50', 'bubble_50', 'bubble_50', 'bubble_50', 'bubble_50']

# %%
for k in key_list:
    print(class_to_rating[k])
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5

# %%
print(class_to_rating.get(class_rating, "Unknown rating"))
# Out:
# 5

# %%
import json

# %%
links = []
for s in soup.find_all("link"):
    int_str = s.get('href')[:25]
    v = int_str.find('tripadvisor')
    if v!= -1:
        links.append(s.get('href'))

# %%
url1 = links[5]
print(url1)
res1 = http.request("GET",url1)
print(res1.data)
soup1 = BeautifulSoup(res1.data)
#print(soup1.prettify())
# Out:
# https://www.tripadvisor.es/Hotel_Review-g41129-d263087-Reviews-or20-Hampton_Inn_Elkton-Elkton_Maryland.html
# C:\Users\dell\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...
